# %%
import sys
sys.path.append('/home/potzschf/repos/')
from helperToolz.helpsters import *
from helperToolz.guzinski import * 
from helperToolz.dicts_and_lists import INT_TO_MONTH
import cfgrib
import pvlib
from pvlib.irradiance import get_total_irradiance
from pvlib.location import Location

os.environ["PROJ_LIB"] = "/data/Aldhani/users/potzschf/conda/envs/cds_era5/share/proj"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from helperToolz.dicts_and_lists import INT_TO_MONTH
#       6 import cfgrib
# ----> 7 import pvlib
#       8 from pvlib.irradiance import get_total_irradiance
#       9 from pvlib.location import Location
#
# ModuleNotFoundError: No module named 'pvlib'

# %%
# get variables downloaded
storPath = '/data/Aldhani/eoagritwin/et/Auxiliary/ERA5/tiff/'
base_path = '/data/Aldhani/eoagritwin/et/Auxiliary/ERA5/grib/'
dem_path = '/data/Aldhani/eoagritwin/et/Auxiliary/DEM/Force_Tiles/DEM/'
variables = [name for name in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, name))]
tiles = getFilelist(dem_path, '.tif')

# %%
variable = 'surface_solar_radiation_downward_clear_sky'#'2m_temperature'

for year in [2019]:#range(2017, 2025, 1):
    files = [file for file in getFilelist(os.path.join(base_path, variable), '.grib') if str(year) in file]
    outDir = f'{storPath}{variable}/{year}/'
    
    os.makedirs(outDir, exist_ok=True)

    for file in files:
        m = int(file.split('_')[-1].split('.')[0])
        if growingSeasonChecker(m):
            month = INT_TO_MONTH[f'{m:02d}']
            warp_ERA5_to_reference(file,
                                dem_path,
                                f'{outDir}{variable}_{year}_{month}.tif')
    else:
        continue
# Out:
# October
# April
# May
# June
# July
# August
# September

# %%
variable = 'geopotential'
year = 2019
files = [file for file in getFilelist(os.path.join(base_path, variable), '.grib') if str(year) in file]

# %%
ds = gdal.Open(files[4])
# Out:
# /data/Aldhani/users/potzschf/conda/envs/cds_era5/lib/python3.12/site-packages/osgeo/gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(

# %%
ds = xr.open_dataset(files[4])
print(ds)
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:     (time: 672, latitude: 37, longitude: 45)
# Coordinates:
#     number      int64 8B ...
#   * time        (time) datetime64[ns] 5kB 2019-02-01 ... 2019-02-28T23:00:00
#     step        timedelta64[ns] 8B ...
#     surface     float64 8B ...
#   * latitude    (latitude) float64 296B 56.0 55.75 55.5 ... 47.5 47.25 47.0
#   * longitude   (longitude) float64 360B 5.0 5.25 5.5 5.75 ... 15.5 15.75 16.0
#     valid_time  (time) datetime64[ns] 5kB ...
# Data variables:
#     z           (time, latitude, longitude) float32 4MB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-07-25T15:01 GRIB to CDM+CF via cfgrib-0.9.1...
# /data/Aldhani/users/potzschf/conda/envs/cds_era5/lib/python3.12/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(

# %%
import matplotlib.pyplot as plt

z_first_layer = ds.z.isel(time=0).values

z_first_layer
# Out:
# array([[ 3.8618164e+00,  2.6860352e+00,  2.9931641e-01, ...,
#          4.6748535e+01,  4.7096191e+01,  4.4033691e+01],
#        [-4.2592773e+00, -9.7802734e-01,  1.0258789e+00, ...,
#         -2.3192871e+01, -2.6001465e+01, -2.1067871e+01],
#        [ 2.9008789e+00, -2.5717773e+00, -2.3803711e+00, ...,
#          5.0170410e+01,  2.8969727e+00, -1.4545898e+00],
#        ...,
#        [ 3.7337915e+03,  2.9718931e+03,  2.6039907e+03, ...,
#          9.9452715e+03,  8.8915098e+03,  6.8455298e+03],
#        [ 3.2186587e+03,  2.4395493e+03,  2.1143892e+03, ...,
#          6.8777837e+03,  5.8188384e+03,  5.0752993e+03],
#        [ 2.5735142e+03,  2.2865259e+03,  2.3169673e+03, ...,
#          4.5810181e+03,  3.4045962e+03,  3.0661118e+03]],
#       shape=(37, 45), dtype=float32)

# %%
ds.z[:, 2, 2].values
# Out:
# array([-2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371,
#        -2.380371, -2.380371, -2.380371, -2.380371, -2.380371, -2.380371],
#       dtype=float32)

# %%
8*60/35
# Out:
# 13.714285714285714
